# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-08-23 00:00:00-04:00', '2024-08-26 00:00:00-04:00',
#                '2024-08-27 00:00:00-04:00', '2024-08-28 00:00:00-04:00',
#                '2024-08-29 00:00:00-04:00', '2024-08-30 00:00:00-04:00',
#                '2024-09-03 00:00:00-04:00', '2024-09-04 00:00:00-04:00',
#                '2024-09-05 00:00:00-04:00', '2024-09-06 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24287, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Stock Splits"]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6363636363636364

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3641
# 1    2596
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5288906009244992

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.535193
# 0    0.464807
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
# 2024-09-06 00:00:00-04:00  5507.330078  5522.470215  5434.129883  5435.839844
#
# ...

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-08-29 00:00:00-04:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 00:00:00-04:00  5612.740234  5651.370117  5581.790039  5648.399902
# 2024-09-03 00:00:00-04:00  5623.890137  5623.890137  5504.330078  5528.930176
# 2024-09-04 00:00:00-04:00  5506.680176  5552.990234  5503.660156  5520.069824
# 2024-09-05 00:00:00-04:00  5520.080078  5546.299805  5480.540039  5503.410156
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4393
# 1.0     843
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5729537366548043

# %%
for lag in [1, 2, 5, 10]:
    sp500.loc[f"Close_Lag_{lag}"] = sp500["Close"].shift(lag)

# %%
# Volatility (standard deviation) over 5 days
sp500.loc["Volatility_5"] = sp500["Close"].rolling(window=5).std()

# %%
# EMA using .loc[]
sp500.loc[:, "EMA_10"] = sp500["Close"].ewm(span=10, adjust=False).mean()

# %%
pip install pandas-ta
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/115.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/115.1 kB ? eta -:--:--
#      ----------------------------- ------- 92.2/115.1 kB 871.5 kB/s eta 0:00:01
#      ------------------------------------ 115.1/115.1 kB 961.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218928 sha256=807b8463b5b34461d9801a80d6cc6cc0cc64da5667a5a585e072500eafdcc9b8
#   Stored in directory: c:\users\jamjh\appdata\local\pip\cache\wheels\fd\ed\18\2a12fd1b7906c63efca6accb351929f2c7f6bbc674e1c0ba5d
# Successfully built pandas-ta
# ...

# %%
import pandas_ta as ta

# Add RSI (Relative Strength Index)
sp500.loc['RSI'] = ta.rsi(sp500["Close"], length=14)

# %%
# Drop rows with missing values
sp500 = sp500.dropna()

# %%
# Calculate the Target using .loc[] to avoid the SettingWithCopyWarning
sp500.loc[:, "Target"] = (sp500["Close"].shift(-1) - sp500["Close"]) / sp500["Close"]

# Apply the lambda function using .loc[] again
sp500.loc[:, "Target"] = sp500["Target"].apply(lambda x: 1 if x > 0.01 else 0)

# %%
# Train a Random Forest model to get feature importances
model.fit(sp500[predictors], sp500["Target"])

# Get the feature importances
importances = pd.Series(model.feature_importances_, index=predictors)

# Select important features (you can define a threshold, e.g., 0.01)
important_features = importances[importances > 0.01].index.tolist()

# %%
from sklearn.model_selection import TimeSeriesSplit

# Define time series cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Iterate through train/test splits
for train_index, test_index in tscv.split(sp500):
    train, test = sp500.iloc[train_index], sp500.iloc[test_index]
    
    # Fit the model
    model.fit(train[important_features], train["Target"])
    
    # Make predictions
    preds = model.predict(test[important_features])

    # Evaluate performance
    print(f"Precision: {precision_score(test['Target'], preds)}")
# Out:
# Precision: 0.16666666666666666
# Precision: 0.5
# C:\Users\jamjh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Precision: 0.0
# C:\Users\jamjh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Precision: 0.0
# Precision: 0.0
# C:\Users\jamjh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(test["Target"].value_counts())
# Out:
# Target
# 0.0    1059
# 1.0     228
# Name: count, dtype: int64

# %%
# Adjust threshold for binary classification
threshold = 0.3  # Lower threshold
preds_proba = model.predict_proba(test[important_features])[:, 1]
preds = (preds_proba >= threshold).astype(int)

# %%
preds_proba = model.predict_proba(test[important_features])
print(preds_proba[:10])  # Print the first 10 probability predictions
# Out:
# [[9.99520272e-01 4.79728490e-04]
#  [9.99710145e-01 2.89855072e-04]
#  [9.88869991e-01 1.11300094e-02]
#  [8.58090064e-01 1.41909936e-01]
#  [8.28177059e-01 1.71822941e-01]
#  [9.41806269e-01 5.81937311e-02]
#  [8.30897896e-01 1.69102104e-01]
#  [9.14383367e-01 8.56166329e-02]
#  [8.57295623e-01 1.42704377e-01]
#  [9.27572795e-01 7.24272047e-02]]

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# Define the resampling pipeline
smote = SMOTE(random_state=1)
pipeline = Pipeline([
    ('smote', smote),
    ('model', model)
])

# Split data into features and target
X_train = sp500[important_features]
y_train = sp500["Target"]

# Fit the pipeline
pipeline.fit(X_train, y_train)

# Predict on test set
preds_proba = pipeline.predict_proba(test[important_features])[:, 1]
preds = (preds_proba >= threshold).astype(int)

# Evaluate
from sklearn.metrics import precision_score, f1_score, roc_auc_score

print(f"Precision: {precision_score(test['Target'], preds, zero_division=0)}")
print(f"F1 Score: {f1_score(test['Target'], preds)}")
print(f"ROC-AUC Score: {roc_auc_score(test['Target'], preds_proba)}")
# Out:
# Precision: 0.24681344148319814
# F1 Score: 0.3904674610449129
# ROC-AUC Score: 0.8237289399135233

# %%
# Adjust threshold and predict
threshold = 0.3
preds = (preds_proba >= threshold).astype(int)

# Evaluate
print(f"Precision: {precision_score(test['Target'], preds, zero_division=0)}")
print(f"F1 Score: {f1_score(test['Target'], preds)}")
print(f"ROC-AUC Score: {roc_auc_score(test['Target'], preds_proba)}")
# Out:
# Precision: 0.24681344148319814
# F1 Score: 0.3904674610449129
# ROC-AUC Score: 0.8237289399135233

# %%
from sklearn.metrics import recall_score, f1_score, roc_auc_score

print(f"Recall: {recall_score(test['Target'], preds)}")
print(f"F1 Score: {f1_score(test['Target'], preds)}")
print(f"ROC-AUC Score: {roc_auc_score(test['Target'], preds_proba)}")
# Out:
# Recall: 0.9342105263157895
# F1 Score: 0.3904674610449129
# ROC-AUC Score: 0.8237289399135233

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Try a different model
model = GradientBoostingClassifier(n_estimators=100, random_state=1)
pipeline = Pipeline([
    ('smote', smote),
    ('model', model)
])

# Fit and evaluate
pipeline.fit(X_train, y_train)
preds_proba = pipeline.predict_proba(test[important_features])[:, 1]
preds = (preds_proba >= threshold).astype(int)

print(f"Precision: {precision_score(test['Target'], preds, zero_division=0)}")
print(f"F1 Score: {f1_score(test['Target'], preds)}")
print(f"ROC-AUC Score: {roc_auc_score(test['Target'], preds_proba)}")
# Out:
# Precision: 0.2186192468619247
# F1 Score: 0.3530405405405405
# ROC-AUC Score: 0.728223415005881

# %%
thresholds = [0.2, 0.3, 0.4, 0.5]
for t in thresholds:
    preds = (preds_proba >= t).astype(int)
    print(f"Threshold: {t}")
    print(f"Precision: {precision_score(test['Target'], preds, zero_division=0)}")
    print(f"Recall: {recall_score(test['Target'], preds)}")
    print(f"F1 Score: {f1_score(test['Target'], preds)}")
    print(f"ROC-AUC Score: {roc_auc_score(test['Target'], preds_proba)}\n")
# Out:
# Threshold: 0.2
# Precision: 0.19313304721030042
# Recall: 0.9868421052631579
# F1 Score: 0.3230437903804738
# ROC-AUC Score: 0.728223415005881
#
# Threshold: 0.3
# Precision: 0.2186192468619247
# Recall: 0.9166666666666666
# F1 Score: 0.3530405405405405
# ROC-AUC Score: 0.728223415005881
#
# Threshold: 0.4
# Precision: 0.25338753387533874
# Recall: 0.8201754385964912
# F1 Score: 0.38716356107660455
# ROC-AUC Score: 0.728223415005881
#
# Threshold: 0.5
# Precision: 0.29541284403669726
# Recall: 0.706140350877193
# F1 Score: 0.4165588615782665
# ROC-AUC Score: 0.728223415005881

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

smote = SMOTE(random_state=1)
X = sp500[important_features]
y = sp500["Target"]

pipeline = Pipeline([
    ('smote', smote),
    ('model', model)
])

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('smote', SMOTE(random_state=1)),
#                 ('model', GradientBoostingClassifier(random_state=1))])

# %%
from imblearn.under_sampling import RandomUnderSampler

undersample = RandomUnderSampler(random_state=1)
pipeline = Pipeline([
    ('undersample', undersample),
    ('model', model)
])

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('undersample', RandomUnderSampler(random_state=1)),
#                 ('model', GradientBoostingClassifier(random_state=1))])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
for lag in [1, 2, 5, 10]:
    sp500.loc[f"Close_Lag_{lag}"] = sp500["Close"].shift(lag)

# %%
sp500.loc["Rolling_Mean_10"] = sp500["Close"].rolling(window=10).mean()
sp500.loc["Rolling_Std_10"] = sp500["Close"].rolling(window=10).std()

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

selector = RFE(RandomForestClassifier(n_estimators=100), n_features_to_select=10)
selector = selector.fit(X_scaled, y)

selected_features = X.columns[selector.support_]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=1),
                           param_grid=param_grid,
                           cv=5,
                           scoring='f1',
                           n_jobs=-1)

grid_search.fit(X_scaled, y)
best_model = grid_search.best_estimator_

# %%
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=1)
model.fit(X_scaled, y)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score

# Predict probabilities
preds_proba = model.predict_proba(test[important_features])[:, 1]

# Precision-Recall curve
precision, recall, _ = precision_recall_curve(test["Target"], preds_proba)

# ROC curve
fpr, tpr, _ = roc_curve(test["Target"], preds_proba)
# Out:
# C:\Users\jamjh\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split

# Example data
X = sp500[['Close_Lag_1', 'Close_Lag_2', 'Rolling_Mean_10', 'Rolling_Std_10']]
y = sp500['Target']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Initialize and fit the model
model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=1)
model.fit(X_train, y_train)

# Make predictions
preds = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[186], line 13
#      11 # Initialize and fit the model
#      12 model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=1)
# ---> 13 model.fit(X_train, y_train)
#      15 # Make predictions
#      16 preds = model.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:659, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
# ...

# %%
print(X_train.isna().sum())
# Out:
# Close_Lag_1         4
# Close_Lag_2         5
# Rolling_Mean_10    13
# Rolling_Std_10     13
# dtype: int64

# %%
# Remove rows with any NaN values
X_train_clean = X_train.dropna()
y_train_clean = y_train.loc[X_train_clean.index]

# %%
from sklearn.impute import SimpleImputer

# Create an imputer object with a strategy to replace NaNs with the median
imputer = SimpleImputer(strategy='median')

# Fit the imputer on the training data and transform both train and test data
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)
